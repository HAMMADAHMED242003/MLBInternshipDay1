# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/student-performance-dataset/Student_Performance.csv")

# %%
for col in df.columns:
    print(col)
# Out:
# student_id
# age
# gender
# school_type
# parent_education
# study_hours
# attendance_percentage
# internet_access
# travel_time
# extra_activities
# study_method
# math_score
# science_score
# english_score
# overall_score
# final_grade

# %%
# Finding Null Values
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# school_type              0
# parent_education         0
# study_hours              0
# attendance_percentage    0
# internet_access          0
# travel_time              0
# extra_activities         0
# study_method             0
# math_score               0
# science_score            0
# english_score            0
# overall_score            0
# final_grade              0
# dtype: int64

# %%
# Finding Duplicates
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 15000        7271   15    male     private        no formal          1.8
# 15001         861   19   other      public    post graduate          0.8
# 15002        5391   15  female     private              phd          1.9
# 15003       13419   16   other     private         graduate          0.7
# 15004        5192   19  female      public    post graduate          4.9
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 15000                   51.6             yes     >60 min              yes
# 15001                   98.3              no   15-30 min               no
# 15002                   62.4             yes   30-60 min              yes
# 15003                   51.4             yes   15-30 min              yes
# 15004                   67.6             yes     <15 min               no
# ...                      ...             ...         ...              ...
# 24995                   55.2             yes   15-30 min               no
# 24996                   97.1             yes     <15 min               no
# 24997                   63.0             yes     <15 min               no
# 24998                   69.4             yes   15-30 min              yes
# 24999                   60.3             yes   30-60 min               no
#
#       study_method  math_score  science_score  english_score  overall_score  \
# 15000        mixed        31.2           25.6           22.9           25.2
# 15001     coaching        54.3           45.4           51.5           53.9
# 15002     textbook        36.0           32.7           28.6           40.0
# 15003     coaching        59.4           23.5           24.6           30.3
# 15004     coaching        78.5           83.9           63.5           69.0
# ...            ...         ...            ...            ...            ...
# 24995        mixed        55.8           48.5           46.7           46.1
# 24996     coaching        64.8           48.2           52.3           56.5
# 24997  group study        50.5           20.3           36.1           36.7
# 24998  group study        13.0           34.2            7.3           34.1
# 24999        mixed        36.5           45.1           16.5           31.4
#
#       final_grade
# 15000           f
# 15001           e
# 15002           f
# 15003           f
# 15004           d
# ...           ...
# 24995           e
# 24996           d
# 24997           f
# 24998           f
# 24999           f
#
# [10000 rows x 16 columns]

# %%
# FInd duplicate student of same ID
df[df['student_id'] == 861]
# Out:
#        student_id  age gender school_type parent_education  study_hours  \
# 860           861   19  other      public    post graduate          0.8
# 15001         861   19  other      public    post graduate          0.8
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 860                     98.3              no   15-30 min               no
# 15001                   98.3              no   15-30 min               no
#
#       study_method  math_score  science_score  english_score  overall_score  \
# 860       coaching        54.3           45.4           51.5           53.9
# 15001     coaching        54.3           45.4           51.5           53.9
#
#       final_grade
# 860             e
# 15001           e

# %%
print(df.duplicated().sum())
print(df.shape)
# Out:
# 10000
# (25000, 16)

# %%
# Remove Duplicates
df.drop_duplicates(inplace=True)
# Out:
# /tmp/ipykernel_856/3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
print(df.shape)
# Out:
# 0
# (15000, 16)

# %%
# Rename Columns
df.rename(columns={
    'math_score':'Math',
    'english_score':'English',
    'science_score':'Science'
},inplace=True)
# Out:
# /tmp/ipykernel_856/3190202486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'school_type', 'parent_education',
#        'study_hours', 'attendance_percentage', 'internet_access',
#        'travel_time', 'extra_activities', 'study_method', 'Math', 'Science',
#        'English', 'overall_score', 'final_grade', 'Average_Score '],
#       dtype='object')

# %%
# Create New columns Average Score and calculate score in this
df['Average_Score']=(df['Math']+df['English']+df['Science'])/3
# Out:
# /tmp/ipykernel_856/3962096756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average_Score']=(df['Math']+df['English']+df['Science'])/3

# %%
df.head()
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  \
# 0                   84.3             yes     <15 min              yes
# 1                   87.8             yes     >60 min               no
# 2                   65.5              no     <15 min               no
# 3                   58.1              no   15-30 min               no
# 4                   61.0             yes   30-60 min              yes
#
#   study_method  Math  Science  English  overall_score final_grade  \
# 0        notes  42.7     55.4     57.0          200.0           e
# 1     textbook  57.6     68.8     64.8           61.3           d
# 2        notes  84.8     95.0     79.2           89.6           b
# 3        notes  44.4     27.5     54.7           41.6           e
# 4  group study   8.9     32.7     30.0           25.4           f
#
#    Average_Score   Average_Score
# 0       51.700000      51.700000
# 1       63.733333      63.733333
# 2       86.333333      86.333333
# 3       42.200000      42.200000
# 4       23.866667      23.866667

# %%
# Create function of performance for apply conditions in Average Score column
def performance(score):
    if score >= 90:
        return "Excellent"
    elif score >= 80:
        return "Good"
    elif score >= 70:
        return "Average"
    else:
        return "Needs Improvement"

# %%
df['Performance']=df['Average_Score'].apply(performance)

# %%
df.head(40)
# Out:
#     student_id  age  gender school_type parent_education  study_hours  \
# 0            1   14    male      public    post graduate          3.1
# 1            2   18  female      public         graduate          3.7
# 2            3   17  female     private    post graduate          7.9
# 3            4   16   other      public      high school          1.1
# 4            5   16  female      public      high school          1.3
# 5            6   19    male      public        no formal          3.8
# 6            7   14  female     private    post graduate          1.8
# 7            8   18  female     private    post graduate          5.6
# 8            9   15   other     private      high school          3.2
# 9           10   14  female      public          diploma          6.8
# 10          11   17  female     private         graduate          6.1
# 11          12   19   other      public    post graduate          4.0
# 12          13   18  female     private      high school          6.8
# 13          14   18   other      public          diploma          1.3
# 14          15   18   other      public      high school          4.9
# 15          16   18   other     private    post graduate          5.0
# 16          17   17   other     private              phd          2.3
# 17          18   14  female      public    post graduate          0.9
# 18          19   19    male      public    post graduate          4.5
# 19          20   16  female      public    post graduate          4.4
# 20          21   17    male     private              phd          5.4
# 21          22   16  female      public          diploma          2.1
# 22          23   15   other      public      high school          1.8
# 23          24   19  female      public              phd          7.8
# 24          25   18    male      public        no formal          1.4
# 25          26   17    male     private          diploma          8.0
# 26          27   16   other      public    post graduate          5.9
# 27          28   18   other     private    post graduate          5.2
# 28          29   17  female     private    post graduate          3.0
# 29          30   16   other      public          diploma          7.0
# 30          31   16   other     private              phd          7.3
# 31          32   15  female     private      high school          5.9
# 32          33   14    male     private        no formal          5.8
# 33          34   17   other      public         graduate          4.2
# 34          35   19  female      public      high school          1.1
# 35          36   14   other     private          diploma          8.0
# 36          37   19   other      public          diploma          0.6
# 37          38   18  female      public      high school          4.2
# 38          39   15  female     private              phd          3.3
# 39          40   17    male      public          diploma          6.3
#
#     attendance_percentage internet_access travel_time extra_activities  \
# 0                    84.3             yes     <15 min              yes
# 1                    87.8             yes     >60 min               no
# 2                    65.5              no     <15 min               no
# 3                    58.1              no   15-30 min               no
# 4                    61.0             yes   30-60 min              yes
# 5                    69.6             yes     >60 min              yes
# 6                    81.6             yes   30-60 min               no
# 7                    59.4             yes     >60 min              yes
# 8                    89.6             yes   15-30 min              yes
# 9                    62.4             yes     >60 min               no
# 10                   90.5             yes   15-30 min               no
# 11                   96.2             yes     <15 min              yes
# 12                   58.2             yes     >60 min               no
# 13                   95.9             yes   30-60 min              yes
# 14                   85.3             yes     <15 min               no
# 15                   94.4             yes   15-30 min              yes
# 16                   67.3             yes     <15 min              yes
# 17                   93.2             yes   15-30 min              yes
# 18                   73.8             yes   30-60 min              yes
# 19                   59.5             yes     <15 min               no
# 20                   99.8             yes     >60 min               no
# 21                   97.4             yes     >60 min              yes
# 22                   56.2              no   30-60 min              yes
# 23                   72.8             yes   15-30 min              yes
# 24                   99.3             yes     <15 min               no
# 25                   77.4             yes     >60 min               no
# 26                   74.9             yes   15-30 min               no
# 27                   59.8             yes     <15 min              yes
# 28                   71.0             yes   15-30 min               no
# 29                   74.9             yes     >60 min              yes
# 30                   85.7             yes   30-60 min              yes
# 31                   72.5             yes     >60 min              yes
# 32                   81.7             yes   30-60 min              yes
# 33                   55.1              no   15-30 min               no
# 34                   88.2             yes   30-60 min               no
# 35                   50.2             yes   30-60 min               no
# 36                   82.1             yes     >60 min               no
# 37                   91.3             yes   15-30 min               no
# 38                   88.3             yes   15-30 min              yes
# 39                   57.4             yes     <15 min              yes
#
#      study_method   Math  Science  English  overall_score final_grade  \
# 0           notes   42.7     55.4     57.0          200.0           e
# 1        textbook   57.6     68.8     64.8           61.3           d
# 2           notes   84.8     95.0     79.2           89.6           b
# 3           notes   44.4     27.5     54.7           41.6           e
# 4     group study    8.9     32.7     30.0           25.4           f
# 5        coaching   51.5     78.3     63.9           63.5           d
# 6        textbook   41.9     29.4     39.2           39.1           f
# 7     group study   56.7     60.1     53.4           69.6           d
# 8           mixed   54.1     59.5     38.3           55.2           d
# 9           mixed   71.9     70.4     81.3           69.6           d
# 10          notes   75.4     82.7     70.8           77.5           c
# 11          notes   62.0     54.7     58.0           65.0           d
# 12          mixed   75.1     80.5     56.2           73.6           c
# 13       textbook   33.6     26.8     50.0           42.5           e
# 14       coaching   88.1     66.1     70.3           69.3           d
# 15       coaching   66.4     76.9     76.1           73.7           c
# 16          mixed   63.1     46.3     57.1           53.5           e
# 17  online videos   57.2     50.5     54.1           49.8           e
# 18  online videos   38.7     69.9     58.3           59.2           d
# 19          mixed   49.9     53.9     60.4           61.9           d
# 20       textbook   84.9     77.6     77.6           81.3           c
# 21    group study   76.7     31.9     39.3           55.0           d
# 22  online videos   41.3     35.2     19.9           33.5           f
# 23          notes  100.0    100.0    100.0           94.6           b
# 24          mixed   38.9     31.2     57.3           41.4           e
# 25       coaching  100.0     87.7     69.3           92.5           b
# 26       textbook   94.6     92.8     86.9           82.5           c
# 27       textbook   42.9     89.9     63.4           75.4           c
# 28          mixed   40.5     44.5     68.1           45.1           e
# 29       textbook   76.1     73.5     71.7           82.6           c
# 30    group study   79.6     86.0     95.4           90.4           b
# 31       textbook   79.3     82.5     77.4           77.1           c
# 32          notes   94.5     72.1     84.8           78.8           c
# 33       coaching   60.5     57.4     72.9           62.2           d
# 34       coaching   39.8     39.6     36.5           46.9           e
# 35  online videos   93.1     99.8    100.0           90.4           b
# 36       coaching   45.9     43.5     35.0           42.0           e
# 37          notes   82.4     73.5     61.7           79.0           c
# 38          notes   53.5     67.4     61.7           66.5           d
# 39          notes   78.1     70.0     63.8           65.4           d
#
#     Average_Score   Average_Score        Performance
# 0        51.700000      51.700000  Needs Improvement
# 1        63.733333      63.733333  Needs Improvement
# 2        86.333333      86.333333               Good
# 3        42.200000      42.200000  Needs Improvement
# 4        23.866667      23.866667  Needs Improvement
# 5        64.566667      64.566667  Needs Improvement
# 6        36.833333      36.833333  Needs Improvement
# 7        56.733333      56.733333  Needs Improvement
# 8        50.633333      50.633333  Needs Improvement
# 9        74.533333      74.533333            Average
# 10       76.300000      76.300000            Average
# 11       58.233333      58.233333  Needs Improvement
# 12       70.600000      70.600000            Average
# 13       36.800000      36.800000  Needs Improvement
# 14       74.833333      74.833333            Average
# 15       73.133333      73.133333            Average
# 16       55.500000      55.500000  Needs Improvement
# 17       53.933333      53.933333  Needs Improvement
# 18       55.633333      55.633333  Needs Improvement
# 19       54.733333      54.733333  Needs Improvement
# 20       80.033333      80.033333               Good
# 21       49.300000      49.300000  Needs Improvement
# 22       32.133333      32.133333  Needs Improvement
# 23      100.000000     100.000000          Excellent
# 24       42.466667      42.466667  Needs Improvement
# 25       85.666667      85.666667               Good
# 26       91.433333      91.433333          Excellent
# 27       65.400000      65.400000  Needs Improvement
# 28       51.033333      51.033333  Needs Improvement
# 29       73.766667      73.766667            Average
# 30       87.000000      87.000000               Good
# 31       79.733333      79.733333            Average
# 32       83.800000      83.800000               Good
# 33       63.600000      63.600000  Needs Improvement
# 34       38.633333      38.633333  Needs Improvement
# 35       97.633333      97.633333          Excellent
# 36       41.466667      41.466667  Needs Improvement
# 37       72.533333      72.533333            Average
# 38       60.866667      60.866667  Needs Improvement
# 39       70.633333      70.633333            Average

# %%
# Saved Cleaned File
df.to_csv("cleaned_student_performance.csv", index=False)
